# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read the dataset
df = pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# 31164  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Year    City      Sport  ... Gender                       Event   Medal
# 0      1896  Athens   Aquatics  ...    Men              100M Freestyle    Gold
# 1      1896  Athens   Aquatics  ...    Men              100M Freestyle  Silver
# 2      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Bronze
# 3      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors    Gold
# 4      1896  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Silver
# ...     ...     ...        ...  ...    ...                         ...     ...
# 31160  2012  London  Wrestling  ...    Men                    Wg 84 KG  Bronze
# 31161  2012  London  Wrestling  ...    Men                    Wg 96 KG    Gold
# 31162  2012  London  Wrestling  ...    Men                    Wg 96 KG  Silver
# 31163  2012  London  Wrestling  ...    Men                    Wg 96 KG  Bronze
# ...

# %%
df.columns
# Out:
# Index(['Year', 'City', 'Sport', 'Discipline', 'Athlete', 'Country', 'Gender',
#        'Event', 'Medal'],
#       dtype='object')

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
cities = df['City'].unique()
print(cities)
# Out:
# ['Athens' 'Paris' 'St Louis' 'London' 'Stockholm' 'Antwerp' 'Amsterdam'
#  'Los Angeles' 'Berlin' 'Helsinki' 'Melbourne / Stockholm' 'Rome' 'Tokyo'
#  'Mexico' 'Munich' 'Montreal' 'Moscow' 'Seoul' 'Barcelona' 'Atlanta'
#  'Sydney' 'Beijing']

# %%
# The length of the array will give you the number of unique cities where the Summer olympics were held
print('The number of required cities are : ' , len(cities))
# Out:
# The number of required cities are :  22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
df.sort_values("Sport", inplace = True) 
mul_filter1 = df["Medal"]=="Gold"
df.where(mul_filter1, inplace = True) 
df.dropna()
# Out:
#          Year       City      Sport  ... Gender                          Event Medal
# 0      1896.0     Athens   Aquatics  ...    Men                 100M Freestyle  Gold
# 19702  1992.0  Barcelona   Aquatics  ...  Women         4X100M Freestyle Relay  Gold
# 19703  1992.0  Barcelona   Aquatics  ...  Women         4X100M Freestyle Relay  Gold
# 19704  1992.0  Barcelona   Aquatics  ...  Women         4X100M Freestyle Relay  Gold
# 19706  1992.0  Barcelona   Aquatics  ...  Women         4X100M Freestyle Relay  Gold
# ...       ...        ...        ...  ...    ...                            ...   ...
# 7986   1948.0     London  Wrestling  ...    Men       67 - 73KG (Welterweight)  Gold
# 7989   1948.0     London  Wrestling  ...    Men       73 - 79KG (Middleweight)  Gold
# 7995   1948.0     London  Wrestling  ...    Men             - 52KG (Flyweight)  Gold
# 7998   1948.0     London  Wrestling  ...    Men     + 87KG (Super Heavyweight)  Gold
# ...

# %%
A = df['Sport'].value_counts().head()
print(A)
# Out:
# Aquatics      1421
# Athletics     1215
# Rowing         890
# Gymnastics     820
# Fencing        552
# Name: Sport, dtype: int64

# %%
x = A.keys()
x = x.array
y = A.values

plt.bar(x, y)
 
plt.xlabel("Sports")
plt.ylabel("No. of Gold medals")
plt.title("Number of Gold Medals earned by the Top 5 sports")
plt.show()

print('The Sport having the most number of Gold Medals is "AQUATICS"')
# Out:
# The Sport having the most number of Gold Medals is "AQUATICS"

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
df['Sport'].unique()
var = df.groupby(['Sport'], sort=False)['Medal'].count()
sport_max = var.nlargest(5)
print(sport_max)
# Out:
# Sport
# Aquatics      4170
# Athletics     3638
# Rowing        2667
# Gymnastics    2307
# Fencing       1613
# Name: Medal, dtype: int64

# %%
x = sport_max.keys()
x = x.array
y = sport_max.values

plt.bar(x, y)
 
plt.xlabel("Sports")
plt.ylabel("No. of medals")
plt.title("Number of Medals earned by the Top 5 sports")
plt.show()
print('The Sport having the most number of Medals is "AQUATICS"')
# Out:
# The Sport having the most number of Medals is "AQUATICS"

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)¶

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
df['Athlete'].unique()
players = df.groupby(['Athlete'], sort=False)['Medal'].count()
players_max = players.nlargest(5)
print(players_max)
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# ONO, Takashi            13
# Name: Medal, dtype: int64

# %%
x = players_max.keys()
x = x.array
y = players_max.values

plt.bar(x, y)
 
plt.xlabel("Players")
plt.ylabel("No. of medals")
plt.title("Number of Medals earned by the Top 5 Players")
plt.show()
print('The Player having the most number of Medals is "PHELPS, Michael"')
# Out:
# The Player having the most number of Medals is "PHELPS, Michael"

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
# df.sort_values("Sport", inplace = True) 
mul_filter1 = df["Medal"]=="Gold"
df.where(mul_filter1, inplace = True) 
df.dropna()
# Out:
#          Year    City      Sport  ... Gender                       Event Medal
# 0      1896.0  Athens   Aquatics  ...    Men              100M Freestyle  Gold
# 3      1896.0  Athens   Aquatics  ...    Men  100M Freestyle For Sailors  Gold
# 6      1896.0  Athens   Aquatics  ...    Men             1200M Freestyle  Gold
# 9      1896.0  Athens   Aquatics  ...    Men              400M Freestyle  Gold
# 13     1896.0  Athens  Athletics  ...    Men                        100M  Gold
# ...       ...     ...        ...  ...    ...                         ...   ...
# 31145  2012.0  London  Wrestling  ...    Men                    Wg 60 KG  Gold
# 31149  2012.0  London  Wrestling  ...    Men                    Wg 66 KG  Gold
# 31153  2012.0  London  Wrestling  ...    Men                    Wg 74 KG  Gold
# 31157  2012.0  London  Wrestling  ...    Men                    Wg 84 KG  Gold
# 31161  2012.0  London  Wrestling  ...    Men                    Wg 96 KG  Gold
#
# ...

# %%
player = df['Athlete'].value_counts()
players_medals = player.nlargest(5)
print(players_medals)
# Out:
# PHELPS, Michael     18
# NURMI, Paavo         9
# SPITZ, Mark          9
# LATYNINA, Larisa     9
# LEWIS, Carl          9
# Name: Athlete, dtype: int64

# %%
x = players_max.keys()
x = x.array
y = players_max.values

plt.bar(x, y)
 
plt.xlabel("Players")
plt.ylabel("No. of medals")
plt.title("Number of Medals earned by the Top 5 Players")
plt.show()
print('The Player having the most number of Medals is "PHELPS, Michael"')
# Out:
# The Player having the most number of Medals is "PHELPS, Michael"

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
mul_filter1 = df["Medal"]=="Gold"
mul_filter2 = df["Country"] == "IND"
df.where(mul_filter1 & mul_filter2, inplace = True) 
print(df.dropna())
print("\n")
print("India won the first Gold medal in summer olympics in the Year 1928.")
# Out:
#          Year       City     Sport  ... Gender                     Event Medal
# 5512   1928.0  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5513   1928.0  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5514   1928.0  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5515   1928.0  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# 5516   1928.0  Amsterdam    Hockey  ...    Men                    Hockey  Gold
# ...       ...        ...       ...  ...    ...                       ...   ...
# 16099  1980.0     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16100  1980.0     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16101  1980.0     Moscow    Hockey  ...    Men                    Hockey  Gold
# 16102  1980.0     Moscow    Hockey  ...    Men                    Hockey  Gold
# 28856  2008.0    Beijing  Shooting  ...    Men  10M Air Rifle (60 Shots)  Gold
#
# [128 rows x 9 columns]
# ...

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players?

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
data = []

for event in df['Event'].unique():
    data.append([event , len(df[df['Event']  == event])])

pd.DataFrame(data,columns = ['Event','freq']).sort_values(by='freq', ascending=False).plot(x = 'Event', y = 'freq', kind = 'bar', figsize = (100,100))
print("\n")
print("The most popular event in terms of number of players is FOOTBALL.")
# Out:
# The most popular event in terms of number of players is FOOTBALL.

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("summer.csv")

# %%
mul_filter1 = df["Medal"]=="Gold"
mul_filter2 = df["Gender"]=="Women"
df.where(mul_filter1 & mul_filter2, inplace = True) 
print(df.dropna())
# Out:
#          Year      City  ...                                    Event Medal
# 417    1900.0     Paris  ...                               Individual  Gold
# 641    1900.0     Paris  ...                            Mixed Doubles  Gold
# 649    1900.0     Paris  ...                                  Singles  Gold
# 710    1904.0  St Louis  ...  Double Columbia Round (50Y - 40Y - 30Y)  Gold
# 713    1904.0  St Louis  ...        Double National Round (60Y - 50Y)  Gold
# ...       ...       ...  ...                                      ...   ...
# 31081  2012.0    London  ...                                     75KG  Gold
# 31097  2012.0    London  ...                                 Wf 48 KG  Gold
# 31105  2012.0    London  ...                                 Wf 55 KG  Gold
# 31113  2012.0    London  ...                                 Wf 63 KG  Gold
# 31121  2012.0    London  ...                                 Wf 72 KG  Gold
#
# [2786 rows x 9 columns]

# %%
female = df['Sport'].value_counts()
female_players_medals = female.nlargest(5)
print(female_players_medals)
# Out:
# Aquatics      589
# Athletics     389
# Gymnastics    268
# Rowing        217
# Volleyball    166
# Name: Sport, dtype: int64

# %%
x = female_players_medals.keys()
x = x.array
y = female_players_medals.values

plt.bar(x, y)
 
plt.xlabel("Female Players")
plt.ylabel("No. of Gold medals")
plt.title("Number of GoldMedals earned by the Top 5 Female Players")
plt.show()
print('The Sport having the most number of Gold Medals won by Females is "AQUATICS"')
# Out:
# The Sport having the most number of Gold Medals won by Females is "AQUATICS"

# %%
""" END """
